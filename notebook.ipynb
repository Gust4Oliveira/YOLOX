# %% [markdown]
# ### Setup Roboflow dataset
# Run `python custom_voc.py <dataset_folder>`

# %% [markdown]
# ### Train model
# Default = ```!python tools/train.py -f exps/example/yolox_voc/yolox_voc_s.py -d 1 -b 16 --fp16 -o -c /content/yolox_s.pth```

# %%
# !python tools/train.py -f exps/example/yolox_voc/yolox_voc_s.py -d 1 -b 16 --fp16 -o -c models/yolox_s.pth

# %% [markdown]
# ### Evaluate model
# Default = ```!python tools/eval.py -n  yolox-s -c YOLOX_outputs/yolox_voc_s/best_ckpt.pth -b 64 -d 1 --conf 0.001 -f exps/example/yolox_voc/yolox_voc_s.py  ```

# %%
# !python tools/eval.py -n  yolox-m -c YOLOX_outputs/yolox_voc_m/best_ckpt.pth -b 64 -d 1 --conf 0.001 -f exps/example/yolox_voc/yolox_voc_m.py

# %% [markdown]
# ### Test the model with images
# Default = ```!python tools/demo.py image -f /content/YOLOX/exps/example/yolox_voc/yolox_voc_s.py -c {MODEL_PATH} --path {TEST_IMAGE_PATH} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu```

# %%
import os

IMG_PATH = 'C:/Users/gusta/OneDrive/Documentos/TCC/Dataset/Pos-notacao_120Seg/120seg-640px.v1i.voc/test-salt_and_pepper/'

MODEL_PATH = 'YOLOX_outputs/yolox_voc_s/best_ckpt.pth'
for file in os.listdir(IMG_PATH):
    if file.endswith('.jpg'):
        # !python tools/demo.py image -f exps/example/yolox_voc/yolox_voc_s.py -c {MODEL_PATH} --path {IMG_PATH}{file} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

MODEL_PATH = 'YOLOX_outputs/yolox_voc_m/best_ckpt.pth'
for file in os.listdir(IMG_PATH):
    if file.endswith('.jpg'):
        # !python tools/demo.py image -f exps/example/yolox_voc/yolox_voc_m.py -c {MODEL_PATH} --path {IMG_PATH}{file} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

MODEL_PATH = 'YOLOX_outputs/yolox_voc_l/best_ckpt.pth'
for file in os.listdir(IMG_PATH):
    if file.endswith('.jpg'):
        # !python tools/demo.py image -f exps/example/yolox_voc/yolox_voc_l.py -c {MODEL_PATH} --path {IMG_PATH}{file} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

MODEL_PATH = 'YOLOX_outputs/yolox_voc_x/best_ckpt.pth'
for file in os.listdir(IMG_PATH):
    if file.endswith('.jpg'):
        # !python tools/demo.py image -f exps/example/yolox_voc/yolox_voc_x.py -c {MODEL_PATH} --path {IMG_PATH}{file} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

MODEL_PATH = 'YOLOX_outputs/yolox_voc_darknet/best_ckpt.pth'
for file in os.listdir(IMG_PATH):
    if file.endswith('.jpg'):
        # !python tools/demo.py image -f exps/example/yolox_voc/yolox_voc_darknet.py -c {MODEL_PATH} --path {IMG_PATH}{file} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

# %% [markdown]
# ### Test the model with video
# Default = ```python tools/demo.py video -f exps/example/yolox_voc/yolox_voc_s.py -c {MODEL_PATH} --path /path/to/your/video --conf 0.25 --nms 0.45 --tsize 640 --save_result --device [gpu]```

# %%
VIDEO_PATH = '"C:\\Users\\gusta\\OneDrive\\Documentos\\TCC\\Dataset\\Pre-Processamento_120Seg\\original_video.mp4"'

MODEL_PATH = 'YOLOX_outputs/yolox_voc_s/best_ckpt.pth'
# !python tools/demo.py video -f exps/example/yolox_voc/yolox_voc_s.py -c {MODEL_PATH} --path {VIDEO_PATH} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

MODEL_PATH = 'YOLOX_outputs/yolox_voc_m/best_ckpt.pth'
# !python tools/demo.py video -f exps/example/yolox_voc/yolox_voc_m.py -c {MODEL_PATH} --path {VIDEO_PATH} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

MODEL_PATH = 'YOLOX_outputs/yolox_voc_l/best_ckpt.pth'
# !python tools/demo.py video -f exps/example/yolox_voc/yolox_voc_l.py -c {MODEL_PATH} --path {VIDEO_PATH} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

MODEL_PATH = 'YOLOX_outputs/yolox_voc_x/best_ckpt.pth'
# !python tools/demo.py video -f exps/example/yolox_voc/yolox_voc_x.py -c {MODEL_PATH} --path {VIDEO_PATH} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

MODEL_PATH = 'YOLOX_outputs/yolox_voc_darknet/best_ckpt.pth'
# !python tools/demo.py video -f exps/example/yolox_voc/yolox_voc_darknet.py -c {MODEL_PATH} --path {VIDEO_PATH} --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu
# Out:
# 2023-03-01 04:43:25.491 | INFO     | __main__:main:257 - Args: Namespace(camid=0, ckpt='YOLOX_outputs/yolox_voc_s/best_ckpt.pth', conf=0.25, demo='video', device='gpu', exp_file='exps/example/yolox_voc/yolox_voc_s.py', experiment_name='yolox_voc_s', fp16=False, fuse=False, legacy=False, name=None, nms=0.45, path='C:\\Users\\gusta\\OneDrive\\Documentos\\TCC\\Dataset\\Pre-Processamento_120Seg\\original_video.mp4', save_result=True, trt=False, tsize=640)
# 2023-03-01 04:43:25.946 | INFO     | __main__:main:267 - Model Summary: Params: 8.94M, Gflops: 26.76
# 2023-03-01 04:43:26.078 | INFO     | __main__:main:280 - loading checkpoint
# 2023-03-01 04:43:26.204 | INFO     | __main__:main:284 - loaded checkpoint done.
# 2023-03-01 04:43:26.223 | INFO     | __main__:imageflow_demo:222 - video save_path is ./YOLOX_outputs\yolox_voc_s\vis_res\2023_03_01_04_43_26\original_video.mp4
# 2023-03-01 04:43:27.533 | INFO     | __main__:inference:164 - Infer time: 1.2983s
# ...

# %% [markdown]
# ### Train the remaining models

# %%
import time
# !python tools/train.py -f exps/example/yolox_voc/yolox_voc_m.py -d 1 -b 16 --fp16 -o -c models/yolox_m.pth
# time.sleep(120)
# !python tools/train.py -f exps/example/yolox_voc/yolox_voc_l.py -d 1 -b 12 --fp16 -o -c models/yolox_l.pth
# time.sleep(120)
# !python tools/train.py -f exps/example/yolox_voc/yolox_voc_x.py -d 1 -b 8 --fp16 -o -c models/yolox_x.pth
# time.sleep(120)
# !python tools/train.py -f exps/example/yolox_voc/yolox_voc_darknet.py -d 1 -b 8 --fp16 -o -c models/yolox_darknet.pth

# %% [markdown]
# ### Apply filters in test dataset

# %% [markdown]
# #### Gaussian blur (https://docs.opencv.org/4.x/d4/d86/group__imgproc__filter.html#gaabe8c836e97159a9193fb0b11ac52cf1)

# %%
import cv2, os

img_dir = r'C:\Users\gusta\OneDrive\Documentos\TCC\Dataset\Pos-notacao_120Seg\120seg-640px.v1i.voc\test'
save_dir = r'C:\Users\gusta\OneDrive\Documentos\TCC\Dataset\Pos-notacao_120Seg\120seg-640px.v1i.voc\test_gaussian_blur'

for filename in os.listdir(img_dir):
    if filename.endswith('.jpg'):
        img = cv2.imread(os.path.join(img_dir,filename))
        result = cv2.GaussianBlur(img,(5,5),cv2.BORDER_DEFAULT)     
        cv2.imwrite(os.path.join(save_dir,filename),result)

# %% [markdown]
# #### Denoise filter (https://docs.opencv.org/4.x/d1/d79/group__photo__denoise.html#ga76abf348c234cecd0faf3c42ef3dc715)

# %%
import cv2, os

img_dir = r'C:\Users\gusta\OneDrive\Documentos\TCC\Dataset\Pos-notacao_120Seg\120seg-640px.v1i.voc\test'
save_dir = r'C:\Users\gusta\OneDrive\Documentos\TCC\Dataset\Pos-notacao_120Seg\120seg-640px.v1i.voc\test_noise'

for filename in os.listdir(img_dir):
    if filename.endswith('.jpg'):
        img = cv2.imread(os.path.join(img_dir,filename))
        result = cv2.fastNlMeansDenoising(img,None,20,7,21)     
        cv2.imwrite(os.path.join(save_dir,filename),result)

# %% [markdown]
# #### Gaussian Noise (https://www.kaggle.com/code/chanduanilkumar/adding-and-removing-image-noise-in-python/notebook)

# %%
import cv2, os
import numpy as np

img_dir = r'C:\Users\gusta\OneDrive\Documentos\TCC\Dataset\Pos-notacao_120Seg\120seg-640px.v1i.voc\test'
save_dir = r'C:\Users\gusta\OneDrive\Documentos\TCC\Dataset\Pos-notacao_120Seg\120seg-640px.v1i.voc\test-gaussian-noise'


for filename in os.listdir(img_dir):
    if filename.endswith('.jpg'):
        img = cv2.imread(os.path.join(img_dir,filename))
        gauss_noise = np.random.normal(0,0.5,img.size)
        gauss_noise = gauss_noise.reshape(img.shape[0],img.shape[1],img.shape[2]).astype('uint8')
        result=cv2.add(img,gauss_noise)
        cv2.imwrite(os.path.join(save_dir,filename),result)

# %% [markdown]
# ### Salt&Pepper Noise (https://gist.github.com/lucaswiman/1e877a164a69f78694f845eab45c381a)

# %%
import cv2, os
import numpy as np

img_dir = r'C:\Users\gusta\OneDrive\Documentos\TCC\Dataset\Pos-notacao_120Seg\120seg-640px.v1i.voc\test'
save_dir = r'C:\Users\gusta\OneDrive\Documentos\TCC\Dataset\Pos-notacao_120Seg\120seg-640px.v1i.voc\test-salt&pepper'


for filename in os.listdir(img_dir):
    if filename.endswith('.jpg'):
        img = cv2.imread(os.path.join(img_dir,filename))
        prob = 0.1
        if len(img.shape) == 2:
            black = 0
            white = 255            
        else:
            colorspace = img.shape[2]
            if colorspace == 3:  # RGB
                black = np.array([0, 0, 0], dtype='uint8')
                white = np.array([255, 255, 255], dtype='uint8')
            else:  # RGBA
                black = np.array([0, 0, 0, 255], dtype='uint8')
                white = np.array([255, 255, 255, 255], dtype='uint8')
        probs = np.random.random(img.shape[:2])
        img[probs < (prob / 2)] = black
        img[probs > 1 - (prob / 2)] = white
        
        cv2.imwrite(os.path.join(save_dir,filename),img)
